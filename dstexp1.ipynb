# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a227-cloud/DSE-Lab/blob/main/dstexp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([1,2,3,4,5])
b=np.arange(1,10,2)
c=np.linspace(0,1,5)
d=np.zeros((2,3))
e=np.ones((2,3))
f=np.eye(3)
g=np.random.randint(1,100,size=(3,3))
print("\n Colum-wise Sum:/n",np.sum(g,axis=0))
print("Row-wise mean:\n",np.mean(g,axis=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2668843873.py in <cell line: 0>()
#       7 f=np.eye(3)
#       8 g=np.random.randint(1,100,size=(3,3))
# ----> 9 print("\n Colum-wise Sum:/n",np.sum(g,azis=0))
#      10 print("Row-wise mean:\n",np.mean(g,axis=1))
#
# TypeError: sum() got an unexpected keyword argument 'azis'
